# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as stats

# %% [markdown]
# # Understanding the data
#
# understanding the above dataet

# %% [markdown]
# # About the dataset

# %% [markdown]
# The data set has been prepared from manual records of road traffic accident of the year 2017-20. All the sensitive information have been excluded during data encoding and finally it has 32 features and 12316 instances of the accident. Then it is preprocessed and for identification of major causes of the accident by analyzing it using different machine learning classification algorithms algorithms. RTA Dataset.csv is the dataset before preprocessing and cleaned.csv is the preprocessed dataset.

# %% [markdown]
# #Descrpition
#
# Time: In which time the accident have been done
#
# Day_of_week: Accident day
#
# Age_band_of_driver: Age of the driver
#
# Sex_of_driver: The drivers gender (Male/Female)
#
# Educational_level: Driver qualification
#
# Vehicle_driver_relation: Relation between the driver and the vehicle
#
# Driving_experience: How long the driver has been roat the vehicle
#
# Type_of_vehicle: vehicle type (petrol/disel/automatic)
#
# Owner_of_vehicle: governmet vehicle or personal
#
# Service_year_of_vehicle: How long the vehicle has been serviced
#
# Vehicle_movement: movement of the vehicle
#
# Casualty_class: it  is used in the context of road traffic accidents to categorize the involvement of individuals in an accident. It helps in analyzing accident data and understanding the different types of casualties involved.
#
# Sex_of_casualty: it refers to the biological sex of a person involved in a road traffic accident. This information is often collected as part of accident data
#
# Age_band_of_casualty: it refers to the age group of a person involved in a road traffic accident. This information is often collected as part of accident data and used for various purposes
#
# Casualty_severity: classification system used in road traffic accident data to categorize the seriousness of injuries sustained by individuals involved in an accident.
#
# Work_of_casuality: data field used in road traffic accident analysis to categorize the occupation or employment status of individuals involved in an accident.
#
# Fitness_of_casuality: data field used in road traffic accident analysis to indicate the physical and mental condition of an individual involved in an accident.
#
# pedestrian_movement: refers to the patterns and behaviors of individuals walking in various environments, including urban areas, parks, and public spaces
#
#
# Cause_of_accident: it  is a critical factor in understanding road traffic accidents. It helps identify patterns, implement preventive measures, and improve overall road safety.
#
# Accident_severity: is a classification system used to categorize the seriousness of injuries and fatalities resulting from a road traffic accident.

# %% [markdown]
# # Target variable
# To find Cause_of_accident	of the addis ababa road traffic dataset for all other data provide

# %%
# Read the dataset
df=pd.read_csv("/content/addis ababa road.csv")
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3      01:06:00      Sunday              18-30          Male
# 4      01:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
# check the shape of the dataset
df.shape
# Out:
# (12316, 32)

# %% [markdown]
# In this dataset their were 12316 rows and 32 columns

# %%
# print the first few data
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3  01:06:00      Sunday              18-30          Male  Junior high school
# 4  01:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# check the first few rows of the dataset

# %%
# print the last few data
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %% [markdown]
# check the last few rows of the dataset

# %%
# print the column names of the dataset
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %% [markdown]
# print all the column names of the dataset

# %%
# check the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# * In this dataset their where 32 columns and 12316 rows
#
# * There where no null values in the data
#
# * In this data their are 30 objects and 2 integers

# %% [markdown]
# #  Data visualisation
#
# visualise the data

# %%
# print all the unique values of the columns
for column in df.columns:
  print("unique values in",column)
  print(df[column].unique())
  print("------------------------------------------")
# Out:
# unique values in Time
# ['17:02:00' '01:06:00' '14:15:00' ... '07:24:00' '19:18:00' '02:47:00']
# ------------------------------------------
# unique values in Day_of_week
# ['Monday' 'Sunday' 'Friday' 'Wednesday' 'Saturday' 'Thursday' 'Tuesday']
# ------------------------------------------
# unique values in Age_band_of_driver
# ['18-30' '31-50' 'Under 18' 'Over 51' 'Unknown']
# ------------------------------------------
# unique values in Sex_of_driver
# ['Male' 'Female' 'Unknown']
# ------------------------------------------
# unique values in Educational_level
# ['Above high school' 'Junior high school' nan 'Elementary school'
#  'High school' 'Unknown' 'Illiterate' 'Writing & reading']
# ------------------------------------------
# unique values in Vehicle_driver_relation
# ['Employee' 'Unknown' 'Owner' nan 'Other']
# ------------------------------------------
# unique values in Driving_experience
# ['1-2yr' 'Above 10yr' '5-10yr' '2-5yr' nan 'No Licence' 'Below 1yr'
# ...

# %% [markdown]
# In this step we call the unique values of the dataset

# %%
df['Time'].value_counts()
# Out:
# Time
# 15:30:00    120
# 17:10:00    110
# 18:30:00    103
# 11:30:00     99
# 17:00:00     98
#            ...
# 19:04:00      1
# 20:36:00      1
# 22:54:00      1
# 21:03:00      1
# 02:47:00      1
# Name: count, Length: 1074, dtype: int64

# %%
import pandas as pd
# Example: Assume your data is already loaded in 'df'
# Convert the Time column to datetime format
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce')

# Define the time ranges for day and night
day_start = pd.to_datetime('06:00:00', format='%H:%M:%S').time()  # 6 AM
day_end = pd.to_datetime('18:00:00', format='%H:%M:%S').time()    # 6 PM

# Create a new column to classify as 'Day' or 'Night'
df['Day_or_Night'] = df['Time'].apply(lambda x: 'Day' if day_start <= x.time() <= day_end else 'Night')

# Check the result
print(df[['Time', 'Day_or_Night']])
# Out:
#                      Time Day_or_Night
# 0     1900-01-01 17:02:00          Day
# 1     1900-01-01 17:02:00          Day
# 2     1900-01-01 17:02:00          Day
# 3     1900-01-01 01:06:00        Night
# 4     1900-01-01 01:06:00        Night
# ...                   ...          ...
# 12311 1900-01-01 16:15:00          Day
# 12312 1900-01-01 18:00:00          Day
# 12313 1900-01-01 13:55:00          Day
# 12314 1900-01-01 13:55:00          Day
# 12315 1900-01-01 13:55:00          Day
#
# [12316 rows x 2 columns]

# %% [markdown]
# in this step we sort the time and convert it into day and night

# %%
# plot the count plot of the accidents by time
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Day_or_Night', palette='rainbow')
plt.title('Count of Accidents', fontsize=16)
plt.xlabel('Time of Day', fontsize=12)
plt.ylabel('Count of accident', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# Out:
# <ipython-input-809-8cbb40200cb6>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Day_or_Night', palette='rainbow')

# %% [markdown]
# In the above plot we can see that most of the vehicles passed (morning 6 am to evening 6 pm) we can finalize that most of the vehicle passed day time
#
# in this step we plot the countplot of the accidents and  we need to find most of accidents happened in day or night . we can see that from the graph most of accidents happened in day

# %%
# take the value count of accident severity
value_counts = df['Accident_severity'].value_counts()
print(value_counts)
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
# Extract labels and sizes for the pie chart
labels = value_counts.index.tolist()  # Get unique severity levels as labels
sizes = value_counts.values.tolist()  # Get corresponding counts as sizes

# Create the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
# autopct formats percentages, startangle rotates the chart

plt.title("Accident Severity Distribution")
plt.axis('equal')  # Ensure a circular pie chart
plt.show()

# %% [markdown]
# In the above chart we can see that most of the people haave been slight injury(84.6%) and then 14.2% people are serious injury and 1.3% people are fatal injury and we can see most of the people are slight injury

# %%
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64

# %% [markdown]
# Age count of the accident person list have been given above

# %%
plt.figure(figsize=(12, 6))
driver_severity = df.pivot_table(
    index="Age_band_of_driver", columns="Sex_of_driver", values="Accident_severity", aggfunc="count"
)
sns.heatmap(driver_severity, annot=True, fmt="d", cmap="Blues", cbar_kws={"label": "Count"})
plt.title("Accident Severity by Age and Sex of Driver", fontsize=16)
plt.xlabel("Sex of Driver")
plt.ylabel("Age Band of Driver")
plt.tight_layout()


plt.show()

# %% [markdown]
# In this heat map we can visualize the Accident severity by Age and sex of driver
#
# * unknown female is injured 569 and unknown male is injured 967 and unidentified male or female is injured 12
#
# * minor female is injured 7 and minor male is injured 807 and minor unidentified male or female is injured 11
#
# * above 51 years old female is injured 31 and above 51 male is injured 1531 and above 51 unidentified male or female is injured 23
#
# * age between 31-50 female injured 39 and age between 31-50 male is injured 3982 and age between 31-50 unidentified male or female injured 66
#
# * age between 18-30 female is injured 55 and age between 18-30 male is injured 4150 and age between 18-30 unidentified male or female is injured 66

# %%
# Bar Chart for Accidents by Day_of_week
plt.figure(figsize=(10, 6))
day_counts = df['Day_of_week'].value_counts()
sns.barplot(x=day_counts.index, y=day_counts.values, palette="viridis")
plt.title("Accidents by Day of Week", fontsize=16)
plt.xlabel("Day of Week")
plt.ylabel("Number of Accidents")
plt.tight_layout()


plt.show()
# Out:
# <ipython-input-814-d234c8355fc1>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=day_counts.index, y=day_counts.values, palette="viridis")

# %% [markdown]
# In the above barplot we can visualize the Accident by day of week
#
# * In sunday average 1500 accidents happen
#
# * In Monday above 1600 accidents happen
#
# * In Tuesday above 1750 accidents happen
#
# * In wednesday above 1750 accidents happen
#
# * In Thursday above 1750 accidents happen
#
# * In Friday above 2000 accidents happen
#
# * In Saturday above 1500 accidents happen
#
# in the above barplot we can visualize that least number of accidents happens on sunday and most number of accidents happens on friday

# %%
# createing a fact grid with columns as survived  =0 and survived = 1
grid = sns.FacetGrid(data=df,col="Accident_severity",height=4,aspect=1,sharey=False)
# Mapping bar plot and the data on to the grid
grid.map(sns.countplot,'Number_of_vehicles_involved',palette=['c','m','hotpink'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning:
# The palette list has fewer values (3) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# Heatmap for Correlations between numeric variables
plt.figure(figsize=(8, 6))
numeric_data = df[['Number_of_vehicles_involved', 'Number_of_casualties']]
correlation_matrix = numeric_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap", fontsize=16)
plt.tight_layout()


plt.show()

# %% [markdown]
# In this correlation heat map number_of_vehicles_involved and number_of_casualities is abbout nearly 1.00 and the correlation co-efficient is about 0.21

# %%
# Set general plot style
sns.set(style="whitegrid")

# Bar Chart for Cause_of_accident
plt.figure(figsize=(12, 6))
cause_counts = df['Cause_of_accident'].value_counts()
sns.barplot(y=cause_counts.index, x=cause_counts.values, palette="viridis")
plt.title("Distribution of Cause of Accident", fontsize=16)
plt.xlabel("Number of Accidents")
plt.ylabel("Cause of Accident")
plt.tight_layout()
# Out:
# <ipython-input-817-1412512e7d8f>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=cause_counts.index, x=cause_counts.values, palette="viridis")

# %% [markdown]
# In this barplot we can visualze that Distribution of cause of accident
#
# * improper parking is below 500
# * unknown is below 500
# * drunk drivng is below 500
# * overload is below 500
# * overspeed is below 500
# * turnover is below

# %%
# Create a facet grid based on Accident_severity
import seaborn as sns
import matplotlib.pyplot as plt
grid = sns.FacetGrid(data=df, col="Accident_severity", height=4, aspect=1, sharey=False)

# Map the countplot onto the grid
grid.map(sns.countplot, "Number_of_vehicles_involved", palette=["black", "brown", "orange"])

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning:
# The palette list has fewer values (3) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# in this accident sivearity the count is about more than 7000  slight injury
#
# in this accident siverity the count is about  more than 800  serious injury
#
# in this accident siverity the count is about more than 100  fatal injury

# %%
for col in df.drop("Accident_severity",axis=1):
  g = sns.FacetGrid(df,col="Accident_severity", height=6 ,aspect=1,sharey=False)
  g.map(sns.countplot,col,palette='Greens')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# ...

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
df['Age_band_of_driver'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Age Band of Driver')
plt.xlabel('Age Band')
plt.ylabel('Count')

# Age_band_of_casualty
plt.subplot(1, 2, 2)
df['Age_band_of_casualty'].value_counts().sort_index().plot(kind='bar', color='aqua')
plt.title('Age Band of Casualty')
plt.xlabel('Age Band')
plt.ylabel('Count')

plt.tight_layout()

# %% [markdown]
# * in the age band od drivers more than 4000 drivers  of age between 18 to 50, more than 1500 drivers of age over 51 , more than 500 drivers of age under 18 and more than 1500 drivers are unknown
#
# * in the age band of casuality more than 3000 drivers are of age between 18 to 30 ,more than 2000 drivers are of age between 31 to 50 ,around 1000 drivers are of over 51 and under 18 and more than 4000 drivers are unknown injured

# %%
#df.hist(layout=(1,6), figsize=(45,5))
#plt.tight_layout()
#plt.show()

# %%
df['Number_of_casualties'].value_counts()
# Out:
# Number_of_casualties
# 1    8397
# 2    2290
# 3     909
# 4     394
# 5     207
# 6      89
# 7      22
# 8       8
# Name: count, dtype: int64

# %%
sns.pairplot(df[['Number_of_vehicles_involved','Number_of_casualties']])

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# cleaning the above dataset

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# check how many null value columns in the dataset

# %%
# dropping columns that can cause imbalance while imputation
lists = ['Vehicle_driver_relation', 'Work_of_casuality', 'Fitness_of_casuality',
         'Day_of_week', 'Casualty_severity', 'Time', 'Sex_of_driver',
         'Educational_level', 'Defect_of_vehicle', 'Owner_of_vehicle',
         'Service_year_of_vehicle', 'Road_surface_type', 'Sex_of_casualty']

df.drop(columns=lists, inplace=True, errors='ignore')

# %% [markdown]
# drop tha column we can imbalance

# %%
# fill missing values with mean column values
df['Driving_experience'].fillna(df['Driving_experience'].mode()[0], inplace=True)
df['Age_band_of_driver'].fillna(df['Age_band_of_driver'].mode()[0], inplace=True)
df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0], inplace=True)
df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0], inplace=True)
df['Road_allignment'].fillna(df['Road_allignment'].mode()[0], inplace=True)
df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0], inplace=True)
df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0], inplace=True)
df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0], inplace=True)
df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0], inplace=True)
# Out:
# <ipython-input-826-b173b5ca14f8>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Driving_experience'].fillna(df['Driving_experience'].mode()[0], inplace=True)
# <ipython-input-826-b173b5ca14f8>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# fill the null values using appropriate methods like mean,median,mode

# %%
df.isnull().sum()
# Out:
# Age_band_of_driver             0
# Driving_experience             0
# Type_of_vehicle                0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Age_band_of_casualty           0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# Day_or_Night                   0
# dtype: int64

# %% [markdown]
# check wheather there is any null values

# %%
df.duplicated().sum()
# Out:
# 7

# %% [markdown]
# to check is there is any null vaues in the dataset

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# drop the duplicates in the dataset

# %%
# dropping the duplicate
df.drop_duplicates(inplace=True)
df.duplicated(keep=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12309 entries, 0 to 12315
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age_band_of_driver           12309 non-null  object
#  1   Driving_experience           12309 non-null  object
#  2   Type_of_vehicle              12309 non-null  object
#  3   Area_accident_occured        12309 non-null  object
#  4   Lanes_or_Medians             12309 non-null  object
#  5   Road_allignment              12309 non-null  object
#  6   Types_of_Junction            12309 non-null  object
#  7   Road_surface_conditions      12309 non-null  object
#  8   Light_conditions             12309 non-null  object
#  9   Weather_conditions           12309 non-null  object
#  10  Type_of_collision            12309 non-null  object
#  11  Number_of_vehicles_involved  12309 non-null  int64
#  12  Number_of_casualties         12309 non-null  int64
# ...

# %% [markdown]
# # Descrptive statistics
#
# describe the above dataset

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12309.000000           12309.00000
# mean                      2.040702               1.54846
# std                       0.688985               1.00738
# min                       1.000000               1.00000
# 25%                       2.000000               1.00000
# 50%                       2.000000               1.00000
# 75%                       2.000000               2.00000
# max                       7.000000               8.00000

# %% [markdown]
# Describe the above dataset e can see that dataset count,mean,std,min,25%,50%,75% etc
# total number of counts in the dataset is 12309, the mean value is 2.040702, standard deviation is 0.688985, minimum value is 1, 25% of the data is 2, 50% of the data is 2, 75% of the data is 2 and the maximum value is 7 in this dataset we can see outliers have been here in the dataset

# %%
df.describe(include=object)
# Out:
#        Age_band_of_driver Driving_experience Type_of_vehicle  \
# count               12309              12309           12309
# unique                  5                  7              17
# top                 18-30             5-10yr      Automobile
# freq                 4269               4187            4149
#
#        Area_accident_occured  \
# count                  12309
# unique                    14
# top                    Other
# freq                    4054
#
#                                         Lanes_or_Medians  \
# count                                              12309
# unique                                                 7
# top     Two-way (divided with broken lines road marking)
# freq                                                4790
#
#                        Road_allignment Types_of_Junction  \
# count                            12309             12309
# unique                               9                 8
# ...

# %% [markdown]
#  top: most frequency occuring category

# %% [markdown]
# In this dataset

# %% [markdown]
# * count: Number of non-null values in the column.
# * unique: Number of unique values in the column.
# * top: The most frequent value in the column.
# * freq: The frequency of the most frequent value.

# %%
# remove the unwanted items
df['Driving_experience'] = df['Driving_experience'].str.replace("yr","year")
df['Driving_experience'] = df['Driving_experience'].str.replace("Above"," ")

# %% [markdown]
# Driving_experience can replace yr to year and remove Above from the dataset

# %%
df['Type_of_vehicle'] = df['Type_of_vehicle'].str.replace("("," ")
df['Type_of_vehicle'] = df['Type_of_vehicle'].str.replace(">"," ")
df['Type_of_vehicle'] = df['Type_of_vehicle'].str.replace(")"," ")
df['Type_of_vehicle'] = df['Type_of_vehicle'].str.replace("Public","Public:")
df['Type_of_vehicle'] = df['Type_of_vehicle'].str.replace("41?100Q"," ")

# %% [markdown]
# Type_of_vehicle can remove the openbracket "(" to " " and remove the closebracket ")" to " " and remove the ">" to " "and replace the Public to Public: and remove the "41?100Q" to " "

# %%
df['Age_band_of_driver'] = df['Age_band_of_driver'].str.replace("Unknown"," ")

# %% [markdown]
# Age_band_of_driver can remove the unknown to " "

# %%
df['Lanes_or_Medians'] = df['Lanes_or_Medians'].str.replace("(divided with broken lines road marking)"," ")

# %% [markdown]
# Lanes_or_Medians can remove divided with broken lines road marking to  " "

# %%
df.head()
# Out:
#   Age_band_of_driver Driving_experience       Type_of_vehicle  \
# 0              18-30            1-2year            Automobile
# 1              31-50             10year  Public:    45 seats
# 2              18-30            1-2year             Lorry
# 3              18-30           5-10year  Public:    45 seats
# 4              18-30            2-5year            Automobile
#
#   Area_accident_occured   Lanes_or_Medians  \
# 0     Residential areas          Two-way
# 1          Office areas  Undivided Two way
# 2    Recreational areas              other
# 3          Office areas              other
# 4      Industrial areas              other
#
#                                  Road_allignment Types_of_Junction  \
# 0                 Tangent road with flat terrain       No junction
# 1                 Tangent road with flat terrain       No junction
# 2                 Tangent road with flat terrain       No junction
# ...

# %% [markdown]
# column names of the dataset

# %%
# convert qualitative data into integers
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x=['Age_band_of_driver', 'Driving_experience', 'Type_of_vehicle',
       'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
       'Types_of_Junction', 'Road_surface_conditions', 'Light_conditions',
       'Weather_conditions', 'Type_of_collision',
       'Number_of_vehicles_involved', 'Number_of_casualties',
       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
       'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity',
       'Day_or_Night']
for i in x:
  df[i] = le.fit_transform(df[i])

# %% [markdown]
# convert the qualitative data into integers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12309 entries, 0 to 12315
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age_band_of_driver           12309 non-null  int64
#  1   Driving_experience           12309 non-null  int64
#  2   Type_of_vehicle              12309 non-null  int64
#  3   Area_accident_occured        12309 non-null  int64
#  4   Lanes_or_Medians             12309 non-null  int64
#  5   Road_allignment              12309 non-null  int64
#  6   Types_of_Junction            12309 non-null  int64
#  7   Road_surface_conditions      12309 non-null  int64
#  8   Light_conditions             12309 non-null  int64
#  9   Weather_conditions           12309 non-null  int64
#  10  Type_of_collision            12309 non-null  int64
#  11  Number_of_vehicles_involved  12309 non-null  int64
#  12  Number_of_casualties         12309 non-null  int64
# ...

# %% [markdown]
# all object values can be converted to integers and check their is any object in this

# %%
df.hist(figsize=(10,6))
# Out:
# array([[<Axes: title={'center': 'Age_band_of_driver'}>,
#         <Axes: title={'center': 'Driving_experience'}>,
#         <Axes: title={'center': 'Type_of_vehicle'}>,
#         <Axes: title={'center': 'Area_accident_occured'}>],
#        [<Axes: title={'center': 'Lanes_or_Medians'}>,
#         <Axes: title={'center': 'Road_allignment'}>,
#         <Axes: title={'center': 'Types_of_Junction'}>,
#         <Axes: title={'center': 'Road_surface_conditions'}>],
#        [<Axes: title={'center': 'Light_conditions'}>,
#         <Axes: title={'center': 'Weather_conditions'}>,
#         <Axes: title={'center': 'Type_of_collision'}>,
#         <Axes: title={'center': 'Number_of_vehicles_involved'}>],
#        [<Axes: title={'center': 'Number_of_casualties'}>,
#         <Axes: title={'center': 'Vehicle_movement'}>,
#         <Axes: title={'center': 'Casualty_class'}>,
#         <Axes: title={'center': 'Age_band_of_casualty'}>],
#        [<Axes: title={'center': 'Pedestrian_movement'}>,
# ...

# %% [markdown]
# # correlation matrix
# relation between correlarion coefficient

# %%
# heat map
x=df.corr()
plt.figure(figsize=(20,10))
sns.heatmap(x,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# This is a heatmap it is used to find the relation between correlation coeffcient

# %% [markdown]
# # outlier detection
#
# detect the outliers of the dataset

# %%
#outliers
df.plot(kind='box',subplots=True,layout=(8,3),figsize=(10,20))
# Out:
# Age_band_of_driver                Axes(0.125,0.798085;0.227941x0.0819149)
# Driving_experience             Axes(0.398529,0.798085;0.227941x0.0819149)
# Type_of_vehicle                Axes(0.672059,0.798085;0.227941x0.0819149)
# Area_accident_occured             Axes(0.125,0.699787;0.227941x0.0819149)
# Lanes_or_Medians               Axes(0.398529,0.699787;0.227941x0.0819149)
# Road_allignment                Axes(0.672059,0.699787;0.227941x0.0819149)
# Types_of_Junction                 Axes(0.125,0.601489;0.227941x0.0819149)
# Road_surface_conditions        Axes(0.398529,0.601489;0.227941x0.0819149)
# Light_conditions               Axes(0.672059,0.601489;0.227941x0.0819149)
# Weather_conditions                Axes(0.125,0.503191;0.227941x0.0819149)
# Type_of_collision              Axes(0.398529,0.503191;0.227941x0.0819149)
# Number_of_vehicles_involved    Axes(0.672059,0.503191;0.227941x0.0819149)
# Number_of_casualties              Axes(0.125,0.404894;0.227941x0.0819149)
# ...

# %% [markdown]
# plot the boxplot of dataset and detect the outliers of the dataset
#
# in some columns there were lot of outliers in the dataset
#
# some of the columns have outliers and some columns doesn't have outliers
#
# To find the unique value of the column Vehicle_movement

# %%
# To reduce the skewness of the dataset
df.info()
x=['Age_band_of_driver', 'Driving_experience', 'Type_of_vehicle',
       'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
       'Types_of_Junction', 'Road_surface_conditions', 'Light_conditions',
       'Weather_conditions', 'Type_of_collision',
       'Number_of_vehicles_involved', 'Number_of_casualties',
       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
       'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity',
       'Day_or_Night']
for i in x:
  df[i]=np.log1p(df[i])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12309 entries, 0 to 12315
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age_band_of_driver           12309 non-null  int64
#  1   Driving_experience           12309 non-null  int64
#  2   Type_of_vehicle              12309 non-null  int64
#  3   Area_accident_occured        12309 non-null  int64
#  4   Lanes_or_Medians             12309 non-null  int64
#  5   Road_allignment              12309 non-null  int64
#  6   Types_of_Junction            12309 non-null  int64
#  7   Road_surface_conditions      12309 non-null  int64
#  8   Light_conditions             12309 non-null  int64
#  9   Weather_conditions           12309 non-null  int64
#  10  Type_of_collision            12309 non-null  int64
#  11  Number_of_vehicles_involved  12309 non-null  int64
#  12  Number_of_casualties         12309 non-null  int64
# ...

# %% [markdown]
# To reduce the skewness of the dataset using log1p

# %%
df
# Out:
#        Age_band_of_driver  Driving_experience  Type_of_vehicle  \
# 0                0.693147            0.693147         0.000000
# 1                1.098612            0.000000         2.302585
# 2                0.693147            0.693147         1.609438
# 3                0.693147            1.386294         2.302585
# 4                0.693147            1.098612         0.000000
# ...                   ...                 ...              ...
# 12311            1.098612            1.098612         1.791759
# 12312            0.000000            1.386294         0.000000
# 12313            1.386294            1.386294         0.693147
# 12314            0.693147            0.000000         1.609438
# 12315            0.693147            1.386294         2.079442
#
#        Area_accident_occured  Lanes_or_Medians  Road_allignment  \
# 0                   2.302585          1.098612         1.791759
# 1                   1.945910          1.609438         1.791759
# ...

# %%
# Remove outliers using IQR metthod
x=['Age_band_of_casualty','Pedestrian_movement','Accident_severity','Day_or_Night']
for i in x:
    data=df[i]
    q1=np.quantile(data,0.25)
    q2=np.quantile(data,0.50)
    q3=np.quantile(data,0.75)
    iqr=q3-q1
    lower_bound=q1-1.5*iqr
    upper_bound=q3+1.5*iqr
    outliers=[j for j in data if j<lower_bound or j>upper_bound]
    print(len(outliers))
    df= df[(df[i] >= lower_bound) &(df[i] <= upper_bound)]
# Out:
# 0
# 926
# 1747
# 0

# %% [markdown]
# # Dimentionality reduction
#
# Reducee the variable in a training dataset

# %%
#from sklearn.decomposition import PCA
#from sklearn.preprocessing import StandardScaler
#sc=StandardScaler()
#x=['Age_band_of_driver', 'Driving_experience', 'Type_of_vehicle',
#       'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
#       'Types_of_Junction', 'Road_surface_conditions', 'Light_conditions',
#       'Weather_conditions', 'Type_of_collision',
#       'Number_of_vehicles_involved', 'Number_of_casualties',
#       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
#       'Pedestrian_movement','Accident_severity',
#       'Day_or_Night']
#a=sc.fit_transform(df[x])
#pca=PCA(n_components=2)
#pca_r=pca.fit_transform(a)
#df['pca']=pca_r[:,0]
#df["pca2"]=pca_r[:,1]

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()
x=df[['Age_band_of_driver', 'Driving_experience', 'Type_of_vehicle',
       'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
       'Types_of_Junction', 'Road_surface_conditions', 'Light_conditions',
       'Weather_conditions', 'Type_of_collision',
       'Number_of_vehicles_involved', 'Number_of_casualties',
       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
       'Pedestrian_movement','Accident_severity',
       'Day_or_Night']]==rs.fit_transform(df[['Age_band_of_driver', 'Driving_experience', 'Type_of_vehicle',
       'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
       'Types_of_Junction', 'Road_surface_conditions', 'Light_conditions',
       'Weather_conditions', 'Type_of_collision',
       'Number_of_vehicles_involved', 'Number_of_casualties',
       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
       'Pedestrian_movement','Accident_severity',
       'Day_or_Night']])

# %% [markdown]
# # Scalling
#
# Process of transforming numerical features in dataset to a common scale

# %%
#from sklearn.preprocessing import MinMaxScaler
#mm=MinMaxScaler()
#df[['Age_band_of_driver', 'Driving_experience', 'Type_of_vehicle',
#       'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
#       'Types_of_Junction', 'Road_surface_conditions', 'Light_conditions',
#       'Weather_conditions', 'Type_of_collision',
#       'Number_of_vehicles_involved', 'Number_of_casualties',
#       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
#       'Pedestrian_movement','Accident_severity',
#       'Day_or_Night']]=mm.fit_transform(df[['Age_band_of_driver', 'Driving_experience', 'Type_of_vehicle',
#        'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
#       'Types_of_Junction', 'Road_surface_conditions', 'Light_conditions',
#      'Weather_conditions', 'Type_of_collision',
#       'Number_of_vehicles_involved', 'Number_of_casualties',
#       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
#       'Pedestrian_movement','Accident_severity',
#       'Day_or_Night']])

# %% [markdown]
# process of transforming data values to a specific range

# %%
# model evaluation
from sklearn.model_selection import train_test_split
y=df["Cause_of_accident"]
x=df.drop(columns=['Cause_of_accident'])
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,shuffle=True)
print(f'x_train:{x_train.shape}\ny_train:{y_train.shape}\nx_test:{x_test.shape}\ny_test:{y_test.shape}')
# Out:
# x_train:(7708, 19)
# y_train:(7708,)
# x_test:(1928, 19)
# y_test:(1928,)

# %%
print(x_train)
y_train
# print(x_test)
y_test
# Out:
#        Age_band_of_driver  Driving_experience  Type_of_vehicle  \
# 7332             1.098612            0.693147         1.609438
# 594              1.609438            0.693147         1.945910
# 12058            0.693147            1.098612         0.000000
# 10807            0.693147            0.693147         2.079442
# 1583             0.693147            1.386294         0.000000
# ...                   ...                 ...              ...
# 7175             1.098612            1.098612         2.079442
# 6509             0.000000            1.386294         2.397895
# 6748             1.098612            0.693147         0.000000
# 1154             0.693147            1.098612         1.609438
# 9177             1.098612            1.098612         2.484907
#
#        Area_accident_occured  Lanes_or_Medians  Road_allignment  \
# 7332                1.945910          1.609438         1.791759
# 594                 1.386294          1.609438         1.791759
# ...

# %% [markdown]
# # initial modelling and hypothesis
#
# hypothesis is a function that maps input and output

# %%
from sklearn.svm import SVR
svm_model = SVR()
# fit the model to the train data
svm_model.fit(x_train,y_train)
# predict the target value of the test data
svm_prediction = svm_model.predict(x_test)
print("SVM_Prediction",svm_prediction)# y_test predict the value
# Out:
# SVM_Prediction [2.24853487 1.93556359 2.47921628 ... 2.24111623 1.99945176 2.45740294]

# %% [markdown]
# predict the tarrget value of the dataset

# %% [markdown]
# # Documentation and reporting
#
# processes that involve creating and sharing information to communicate effectively

# %%
# calculating error
from sklearn.metrics import mean_absolute_error
svm_mae=mean_absolute_error(y_test,svm_prediction)
print("Mean absolute error of SVM = ",svm_mae)
# Out:
# Mean absolute error of SVM =  0.7993523304415622

# %% [markdown]
# mean absolute error of support vector machine is 0.2369053403096406

# %%
from sklearn.metrics import mean_squared_error
import math # Import the math module

svm_mse=mean_squared_error(y_test,svm_prediction)
svm_rmse=math.sqrt(svm_mse)  # Use math.sqrt to calculate the square root
print("Root Mean Squared Error of SVM",svm_rmse)
# Out:
# Root Mean Squared Error of SVM 1.0463954979705092

# %% [markdown]
# root mean square of support vector machine is 0.2896359136823333

# %%
# to find the accuracy of the above dataset
from sklearn.metrics import r2_score
r=r2_score(y_test,svm_prediction)
r
# Out:
# -0.24301223795365567

# %% [markdown]
# statistical metric used in machine learning to evaluate a regression model's quality is 0.14533779464741514
#
# #  problem statement
#
# In this model it shows high accurancy in Support vector machine(0.14533779464741514)
#
# first in the data set there in an unwanted column in it.so first drop it from the data set
#
# there are so many null values in this data set so fill these values using its corresponding mod values
#
# then remove the duplicate and clean the data
#
# replace the unwanted string from the coloums and clean it to change its data type int float
#
# then convert all datas into float
#
# plot the visualaisation of the data set for the better understanding
#
# plot the heatmap and remove the higly correlated features to the target variable
#
# find the skew and remove it using log and remove the outlayers using iqr method scale the data to get the best result from it
#
# split the 20 percentage of the data into testing and remaining into training
#
# create the model using Support vector machine and predict the data using xtest
#
# evaluate the accurancy of the model and find the error
